# %%
import pandas as pd

# %%
data = ("assets/temperaturedata.csv")

# %%
df = pd.read_csv(data)

# %%
df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Druzhba  52.0428   33.9453     68.04        94          47
# 1               Dikson  73.5069   80.5464     31.86        86         100
# 2          Mâncio Lima  -7.6142  -72.8958     75.33        76          81
# 3              Ivankiv  50.9386   29.8943     73.60        92          36
# 4               Hobart -42.8794  147.3294     46.11        91           0
# ..                 ...      ...       ...       ...       ...         ...
# 537       Besskorbnaya  44.6447   41.3110     66.16        85           1
# 538  Paso de los Toros -32.8167  -56.5167     52.52        89           0
# 539            Karatau  43.1667   70.4667     57.00        44          26
# 540           Smithers  54.7804 -127.1743     73.72        33          20
# 541           Barcelos  41.5388   -8.6151     61.84        88          37
#
#      Windspeed Country        Date
# 0         7.18      UA  1624405444
# ...

# %%
data_html = df.to_html("data.html")
